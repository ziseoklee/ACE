# %%
import os
from datetime import datetime
import pandas as pd
import numpy as np


# ess ablation for custom_poly
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']ESS_tuning0.7/experiment_results_numseeds5_bs5000_n_steps100.csv" # 0.16
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100.csv"              # 0.43
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']ESS_tuning0.3/experiment_results_numseeds5_bs5000_n_steps100.csv" # 1.74
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']ESS_tuning0.5/experiment_results_numseeds5_bs5000_n_steps100.csv" # 2.26
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']ESS_tuning0.1/experiment_results_numseeds5_bs5000_n_steps100.csv" # 2.35

# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000.csv"

# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7.csv"
# stats_csv_path = "STATS_path_collapse_result_ess_0.7_bs10k_n_steps1000.csv"

# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g1.399999976158142.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g1.600000023841858.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g1.2000000476837158.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g1.7999999523162842.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g1.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g2.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g4.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g6.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs5000_n_steps100_annealing/experiment_results_numseeds5_bs5000_n_steps100_ess0.7_g8.csv"
# stats_csv_path = "STATS_annealing_ess0.7_bs5k_nsteps100_g8.0.csv"

# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100_g-1.0.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100_g-1.2.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100_g-1.4.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100_g-1.6.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100_g-2.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100_g-4.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs5000_n_steps100_g-6.csv"
# stats_csv_path = "STATS_sigmoid_annealing_bs5k_nsteps100_g6.csv"

# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000_g-1.0.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000_g-1.2.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000_g-1.4.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000_g-1.6.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000_g-2.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000_g-4.csv"
# result_csv_path = "#Final_Evaluation_Results#_yesterday/['sigmoid', 'default_linear', 'default_linear']/experiment_results_numseeds5_bs10000_n_steps1000_g-6.csv"
# stats_csv_path = "STATS_sigmoid_annealing_bs10k_nsteps1k_g6.csv"

# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7.csv"
# stats_csv_path = "STATS_path_collapse_result_ess0.7_bs10k_n_steps1000_t_max=0.85.csv"


# # Bump functions ablation study
# Bump = 100
# result_csv_path = f"#Final_Evaluation_Results#_fixed_(Bump case)/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_Bump{Bump}/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7.csv"
# stats_csv_path = f"STATS_path_collapse_result_ess0.7_bs10k_n_steps1000_BUMP_Ablation_{Bump}.csv"
# result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7.csv"
# stats_csv_path = "STATS_path_collapse_result_ess_0.7_bs10k_n_steps1000_Ablation_CUSTOM.csv"

result_csv_path = "[251114] Rebuttal Experiments/['default_linear', 'custom_poly', 'default_linear']/experiment_results_numseeds1_bs10000_n_steps100_['default_linear', 'custom_poly', 'default_linear']_ANNEAL=1.0_BUMP=30.0.csv" 
stats_csv_path = "[251114] Rebuttal Experiments/['default_linear', 'custom_poly', 'default_linear']/[STATS]experiment_results_numseeds1_bs10000_n_steps100_['default_linear', 'custom_poly', 'default_linear']_ANNEAL=1.0_BUMP=30.0.csv"

results_csv = pd.read_csv(result_csv_path)
print(f"Results loaded from {result_csv_path}")
stats_by_method = results_csv.groupby('method').agg({
    'W1':           ['min', 'mean', 'std'],
    'W2':           ['min', 'mean', 'std'],
    'MMD_RBF':      ['min', 'mean', 'std'],
    'Total Var.':   ['min', 'mean', 'std']
}).reset_index()
print(stats_by_method)
stats_by_method.to_csv(stats_csv_path, index=False)
print(f"Stats summary saved to {stats_csv_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 62
#      59 result_csv_path = "[251114] Rebuttal Experiments/['cos_t', 'ddpm_linear', '1-t**2']_ANNEAL=1.0_BUMP=10.0/results_anneal1.0_numseeds5_bs1000_nsteps100.csv"
#      60 stats_csv_path = "[251114] Rebuttal Experiments/['default_linear', 'custom_poly', 'default_linear']/[STATS]experiment_results_numseeds1_bs10000_n_steps100_['default_linear', 'custom_poly', 'default_linear']_ANNEAL=1.0_BUMP=10.0.csv"
# ---> 62 results_csv = pd.read_csv(result_csv_path)
#      63 print(f"Results loaded from {result_csv_path}")
#      64 stats_by_method = results_csv.groupby('method').agg({
#      65     'W1':           ['min', 'mean', 'std'],
#      66     'W2':           ['min', 'mean', 'std'],
#      67     'MMD_RBF':      ['min', 'mean', 'std'],
#      68     'Total Var.':   ['min', 'mean', 'std']
#      69 }).reset_index()
#
# File /mnt/nas5/AIBL-Research/jihyung/playground/2D-HCG/Image-HCG/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /mnt/nas5/AIBL-Research/jihyung/playground/2D-HCG/Image-HCG/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /mnt/nas5/AIBL-Research/jihyung/playground/2D-HCG/Image-HCG/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /mnt/nas5/AIBL-Research/jihyung/playground/2D-HCG/Image-HCG/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /mnt/nas5/AIBL-Research/jihyung/playground/2D-HCG/Image-HCG/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: "[251114] Rebuttal Experiments/['cos_t', 'ddpm_linear', '1-t**2']_ANNEAL=1.0_BUMP=10.0/results_anneal1.0_numseeds5_bs1000_nsteps100.csv"

# %%
import pandas as pd

result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7.csv"
stats_csv_path = "STATS_path_collapse_result_ess0.7_bs10k_n_steps1000_t_max=0.85_3seed.csv"

result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_bs10000_n_steps1000_annealing/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7_g1.csv"
stats_csv_path  = "STATS_annealing_ess0.7_bs10k_nsteps1000_g1_3seed.csv"

result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-1.399999976158142.csv"
result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-1.0.csv"
result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-1.600000023841858.csv"
result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-1.2000000476837158.csv"
result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-1.7999999523162842.csv"
result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-2.csv"
result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-4.csv"
result_csv_path = "#Final_Evaluation_Results#/['sigmoid', 'default_linear', 'default_linear']_sigmoid_bs10000_n_steps1000_ess0.7/experiment_results_numseeds5_bs10000_n_steps1000_g-6.csv"
stats_csv_path = "STATS_sigmoid_annealing_bs10k_nsteps1k_tmax0.85_g6.csv"

result_csv_path = "#Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_Bump14/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7.csv"
stats_csv_path = "STATS_path_collapse_result_ess0.7_bs10k_n_steps1000_t_max=0.85_3seed_Bump14.csv"


results_csv = pd.read_csv(result_csv_path)
print(f"Results loaded from {result_csv_path}")

metrics = ['W1', 'W2', 'MMD_RBF', 'Total Var.']

rows = []
for method, df in results_csv.groupby('method'):
    row = {'method': method}
    for metric in metrics:
        # Select bottom 3 seeds (largest values, since "bottom" = worst)
        bottom3 = df.nsmallest(3, metric)[metric].values
        
        row[f'{metric}_min']  = bottom3.min()
        row[f'{metric}_mean'] = bottom3.mean()
        row[f'{metric}_std']  = bottom3.std(ddof=1) if len(bottom3) > 1 else 0.0
    rows.append(row)

stats_by_method = pd.DataFrame(rows)
print(stats_by_method)

stats_by_method.to_csv(stats_csv_path, index=False)
print(f"Stats summary saved to {stats_csv_path}")
# Out:
# Results loaded from #Final_Evaluation_Results#/['default_linear', 'custom_poly', 'default_linear']_Best_ESS_0.7_Bump14/experiment_results_numseeds5_bs10000_n_steps1000_ess0.7.csv
#   method    W1_min   W1_mean    W1_std    W2_min   W2_mean    W2_std  \
# 0    ACE  0.288665  0.310402  0.025423  0.401184  0.433048  0.043921
# 1  FKC-H  1.942531  2.058712  0.105027  2.275481  2.385279  0.105753
# 2     NR  0.768902  0.780477  0.019669  1.056305  1.068032  0.020169
#
#    MMD_RBF_min  MMD_RBF_mean  MMD_RBF_std  Total Var._min  Total Var._mean  \
# 0     0.025748      0.029506     0.003939        0.622361         0.628578
# 1     1.069784      1.390098     0.278308        0.892063         0.898793
# 2     0.066462      0.067740     0.001304        0.589400         0.593094
#
#    Total Var._std
# 0        0.006377
# 1        0.007978
# 2        0.003308
# Stats summary saved to STATS_path_collapse_result_ess0.7_bs10k_n_steps1000_t_max=0.85_3seed_Bump14.csv

# %% [markdown]
# [DiffDec]
# len: 16: -8.35445
# len: 18: -8.39448
# len: 15: -7.81249
# len: 14: -6.72482
# len: 17: -8.85164
# len: 16: -4.54711
# len: 17: -6.92383
# len: 19: -8.71386
# len: 14: -7.03375
# len: 17: -8.71458
#
# [Delete]
# len: 11: -6.51
# len: 12: -7.29
# len: 13: -7.84
# len: 13: -7.56
# len: 14: -8.33
# len: 14: -8.06
# len: 15: -8.6
# len: 15: -8.97
# len: 15: -8.77
# len: 15: -7.82
#
# [Ours] len = 21 (reference length)
# len: 21: -9.27
# len: 21: -9.17
# len: 21: -9.32
# len: 21: -9.27
# len: 21: -9.86
# len: 21: -11.58
# len: 21: -11.72
# len: 21: -11.66
# len: 21: -11.48
# len: 21: -11.75

# %% [markdown]
# # Evaluation with Metrics
#
# Following the FKC paper, we sample 10k samples with 1000 sampling steps.

# %%
# %reload_ext autoreload
# %autoreload 2

import torch
import matplotlib.pyplot as plt
import numpy as np
import random, os
from datetime import datetime
import os
import torch
import numpy as np
import pandas as pd
from utils.metrics.export import compute_sample_based_metrics
from hcg.interpolant import MLPInstFlexible, run_training_v_s
from hcg.sample_data import sample_checkerboard, make_conditions, sample_data_model1, sample_data_model2, sample_data_model3, ground_truth_hcg, plot_diagnostics
from hcg.hcg import simulate_hcg, simulate_hcg_generalized
from hcg.interpolant import Interpolant as Interpolant
from hcg.interpolant import FlowMatcher as FlowMatcher
from hcg.interpolant import plot_path_trajectories as plot_path_trajectories
import json
from IPython.display import clear_output

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(0); random.seed(0); np.random.seed(0)
print("device →", device)

top_experiment_id = "#Final_Evaluation_Results#"  # Use a fixed ID for reproducibility
if not os.path.exists(top_experiment_id):
    os.makedirs(top_experiment_id)

model_path = "PretrainedToyModels"

def load_interpolants_from_json(path):
    """Load interpolants.json and return a dict of Interpolant objects."""
    with open(path, "r") as f:
        interpolants_raw = json.load(f)

    interpolants = {}
    for name, funcs in interpolants_raw.items():
        alpha_t = eval(funcs["alpha_t"], {"torch": torch})
        beta_t = eval(funcs["beta_t"], {"torch": torch})
        d_alpha_t = eval(funcs["d_alpha_t"], {"torch": torch})
        d_beta_t = eval(funcs["d_beta_t"], {"torch": torch})
        interpolants[name] = Interpolant(alpha_t, beta_t, d_alpha_t, d_beta_t, name=name)
    return interpolants

interpolant_schedules = load_interpolants_from_json("interpolant_schedules.json")
# Out:
# device → cuda

# %%
bs = 10000; n_steps=1000
A, B = 1, 1  # Conditions to use for training
# plot ground truth
# samples_gt = ground_truth_hcg(bs, cond_A=A, cond_B=B).cpu().numpy()
# plot_diagnostics(samples_gt, torch.zeros(bs), [torch.zeros(bs)], save_name=f"{top_experiment_id}/ground_truth")
# clear_output()

# %% [markdown]
# # Experiment 1

# %%
names = ["default_linear", "custom_poly", "default_linear"]
subexperiment_id = f"{names}"
experiment_id = f"{top_experiment_id}/{subexperiment_id}"
if not os.path.exists(experiment_id):
    os.makedirs(experiment_id)

u_model1 = MLPInstFlexible(z_dim=1, cond_dim=1, width=256, depth=4, output_dim=1).to(device); u_model1.load_state_dict(torch.load(f"{model_path}/u_model1_X_given_A_alpha={names[0]}.pth")); u_model1.eval()
s_model1 = MLPInstFlexible(z_dim=1, cond_dim=1, width=256, depth=4, output_dim=1).to(device); s_model1.load_state_dict(torch.load(f"{model_path}/s_model1_X_given_A_alpha={names[0]}.pth")); s_model1.eval()
u_model2 = MLPInstFlexible(z_dim=2, cond_dim=1, width=256, depth=4, output_dim=2).to(device); u_model2.load_state_dict(torch.load(f"{model_path}/u_model2_XY_given_B_alpha={names[2]}.pth")); u_model2.eval()
s_model2 = MLPInstFlexible(z_dim=2, cond_dim=1, width=256, depth=4, output_dim=2).to(device); s_model2.load_state_dict(torch.load(f"{model_path}/s_model2_XY_given_B_alpha={names[2]}.pth")); s_model2.eval()
u_model3 = MLPInstFlexible(z_dim=1, cond_dim=0, width=256, depth=4, output_dim=1).to(device); u_model3.load_state_dict(torch.load(f"{model_path}/u_model3_X_alpha={names[1]}.pth")); u_model3.eval()
s_model3 = MLPInstFlexible(z_dim=1, cond_dim=0, width=256, depth=4, output_dim=1).to(device); s_model3.load_state_dict(torch.load(f"{model_path}/s_model3_X_alpha={names[1]}.pth")); s_model3.eval()

def v1_fn(x, t, A): return u_model1(x, t, A)
def s1_fn(x, t, A): return s_model1(x, t, A)
def v2_fn(x, t): return u_model3(x, t)
def s2_fn(x, t): return s_model3(x, t)
def v3_fn(z, t, B): return u_model2(z, t, B)
def s3_fn(z, t, B): return s_model2(z, t, B)
def sigma_fn(t): return 0.5 * torch.ones_like(t)

v_fn_list=[
        lambda x, t: v1_fn(x[:, :1], t, torch.full((x.size(0), 1), A, device=x.device)), # v1(X|A)
        lambda x, t: v2_fn(x[:, :1], t),                                                 # v2(X)
        lambda x, t: v3_fn(x, t, torch.full((x.size(0), 1), B, device=x.device))         # v3(Z|B)
    ]
s_fn_list=[
        lambda x, t: s1_fn(x[:, :1], t, torch.full((x.size(0), 1), A, device=x.device)), # s1(X|A)
        lambda x, t: s2_fn(x[:, :1], t),                                                 # s2(X)
        lambda x, t: s3_fn(x, t, torch.full((x.size(0), 1), B, device=x.device))         # s3(Z|B)
    ]
proj_list=[
        lambda z: z[:, :1],    # project to X 
        lambda z: z[:, :1],    # project to X
        lambda z: z            # identity for Z
    ]
emb_list=[
        lambda x: torch.cat([x, torch.zeros(x.size(0), 1, device=x.device)], dim=1),  # embed X→Z
        lambda x: torch.cat([x, torch.zeros(x.size(0), 1, device=x.device)], dim=1),  # embed X→Z
        lambda z: z  # identity
    ]

print("Models loaded.")
# Out:
# Models loaded.

# %%
results = []
# seeds=[0,1,2,3,4]
bs = 5000; n_steps=100
seeds = [0]
for seed in seeds:
    torch.manual_seed(seed)
    np.random.seed(seed)
    samples_gt = ground_truth_hcg(bs, cond_A=A, cond_B=B).numpy()
    print(f"Seed set to {seed}")

    print("Simulating NR")
    gamma_list = [
        lambda t : torch.tensor(1),
        lambda t : torch.tensor(1) * torch.tensor(-1) ,
        lambda t : torch.tensor(1)
    ]
    d_gamma_list = [
        lambda t: torch.zeros_like(t),
        lambda t: torch.zeros_like(t),
        lambda t: torch.zeros_like(t)
    ]
    
    x0 = torch.randn(bs, 2).to("cuda")  # (X, Y) sample
    A, B = 1, 1  # Conditioning values
    samples, logw_final, logw_history, sample_history, resample_history = simulate_hcg_generalized(
        x0=x0, v_fn_list=v_fn_list, s_fn_list=s_fn_list, proj_list=proj_list, emb_list=emb_list, sigma_fn=sigma_fn,
        v_star= lambda z, t: v3_fn(z, t, torch.full((z.size(0), 1), B, device=z.device)), 
        t0=0.0, t1=1.0, n_steps=n_steps, device="cuda", ess_threshold=0.90, print_resample_history=True,
        gamma_list=gamma_list,
        d_gamma_list=d_gamma_list,
        resample=False
    )
    samples = samples.cpu().numpy()
    if seed == 0:
        plot_diagnostics(samples, logw_final, logw_history, save_name=f"{experiment_id}/alpha={names}_NR")
        plot_path_trajectories(sample_history, n_frame=6, resample_history=None, experiment_id=experiment_id, name=f"alpha={names}_NR", deg=-50)
        plt.close(); clear_output()
    
    # print("Evaluating NR")
    # w1, w2, mmd_rbf, total_var = compute_sample_based_metrics(
    #     torch.tensor(samples_gt), torch.tensor(samples)
    # )
    # results.append([seed, "NR", w1, w2, mmd_rbf, total_var])

    print("Simulating FKC-H (Constant Gammas)")
    gamma_list = [
        lambda t : torch.tensor(1),
        lambda t : torch.tensor(1) * torch.tensor(-1) ,
        lambda t : torch.tensor(1)
    ]
    d_gamma_list = [
        lambda t: torch.zeros_like(t),
        lambda t: torch.zeros_like(t),
        lambda t: torch.zeros_like(t)
    ]

    x0 = torch.randn(bs, 2).to("cuda")  # (X, Y) sample
    A, B = 1, 1  # Conditioning values
    samples, logw_final, logw_history, sample_history, resample_history = simulate_hcg_generalized(
        x0=x0, v_fn_list=v_fn_list, s_fn_list=s_fn_list, proj_list=proj_list, emb_list=emb_list, sigma_fn=sigma_fn,
        v_star= lambda z, t: v3_fn(z, t, torch.full((z.size(0), 1), B, device=z.device)), 
        t0=0.0, t1=1.0, n_steps=n_steps, device="cuda", ess_threshold=0.90, print_resample_history=True,
        gamma_list=gamma_list,
        d_gamma_list=d_gamma_list,
        resample=True
    )
    samples = samples.cpu().numpy()
    if seed == 0:
        plot_diagnostics(samples, logw_final, logw_history, save_name=f"{experiment_id}/alpha={names}_FKC-H")
        plot_path_trajectories(sample_history, n_frame=6, resample_history=None, experiment_id=experiment_id, name=f"alpha={names}_FKC-H", deg=-50)
        plt.close(); clear_output()

    # print("Evaluating FKC-H")
    # w1, w2, mmd_rbf, total_var = compute_sample_based_metrics(
    #     torch.tensor(samples_gt), torch.tensor(samples)
    # )
    # results.append([seed, "FKC-H", w1, w2, mmd_rbf, total_var])

    print("Simulating ACE (Adaptive Gammas)")
    gamma_list = [
        lambda t : torch.tensor(1),
        lambda t : torch.tensor(1) * torch.tensor(-1) * torch.tensor((1-2*t)**2),
        lambda t : torch.tensor(1)
    ]
    d_gamma_list = [
        lambda t: torch.zeros_like(t),
        lambda t: torch.zeros_like(t) + torch.tensor(-8*t + 4),
        lambda t: torch.zeros_like(t)
    ]

    x0 = torch.randn(bs, 2).to("cuda")  # (X, Y) sample
    A, B = 1, 1  # Conditioning values
    samples, logw_final, logw_history, sample_history, resample_history = simulate_hcg_generalized(
        x0=x0, v_fn_list=v_fn_list, s_fn_list=s_fn_list, proj_list=proj_list, emb_list=emb_list, sigma_fn=sigma_fn,
        v_star= lambda z, t: v3_fn(z, t, torch.full((z.size(0), 1), B, device=z.device)), 
        t0=0.0, t1=1.0, n_steps=n_steps, device="cuda", ess_threshold=0.90, print_resample_history=True,
        gamma_list=gamma_list,
        d_gamma_list=d_gamma_list,
        resample=True
    )
    samples = samples.cpu().numpy()
    if seed == 0:
        plot_diagnostics(samples, logw_final, logw_history, save_name=f"{experiment_id}/alpha={names}_ACE")
        plot_path_trajectories(sample_history, n_frame=6, resample_history=None, experiment_id=experiment_id, name=f"alpha={names}_ACE", deg=-50)
        plt.close(); clear_output()

    # print("Evaluating ACE")
    # w1, w2, mmd_rbf, total_var = compute_sample_based_metrics(
    #     torch.tensor(samples_gt), torch.tensor(samples)
    # )
    # results.append([seed, "ACE", w1, w2, mmd_rbf, total_var])

df = pd.DataFrame(results, columns=["seed", "method", "W1", "W2", "MMD_RBF", "Total Var."])
df.to_csv(f"{experiment_id}/experiment_results_numseeds{len(seeds)}_bs{bs}_n_steps{n_steps}.csv", index=False)
print(df)
# Out:
# Empty DataFrame
# Columns: [seed, method, W1, W2, MMD_RBF, Total Var.]
# Index: []

# %% [markdown]
# # Experiment 2. Annealing

# %%
names = ["sigmoid", "default_linear", "default_linear"]
subexperiment_id = f"{names}"
experiment_id = f"{top_experiment_id}/{subexperiment_id}"
if not os.path.exists(experiment_id):
    os.makedirs(experiment_id)

u_model1 = MLPInstFlexible(z_dim=1, cond_dim=1, width=256, depth=4, output_dim=1).to(device); u_model1.load_state_dict(torch.load(f"{model_path}/u_model1_X_given_A_alpha={names[0]}.pth")); u_model1.eval()
s_model1 = MLPInstFlexible(z_dim=1, cond_dim=1, width=256, depth=4, output_dim=1).to(device); s_model1.load_state_dict(torch.load(f"{model_path}/s_model1_X_given_A_alpha={names[0]}.pth")); s_model1.eval()
u_model2 = MLPInstFlexible(z_dim=2, cond_dim=1, width=256, depth=4, output_dim=2).to(device); u_model2.load_state_dict(torch.load(f"{model_path}/u_model2_XY_given_B_alpha={names[2]}.pth")); u_model2.eval()
s_model2 = MLPInstFlexible(z_dim=2, cond_dim=1, width=256, depth=4, output_dim=2).to(device); s_model2.load_state_dict(torch.load(f"{model_path}/s_model2_XY_given_B_alpha={names[2]}.pth")); s_model2.eval()
u_model3 = MLPInstFlexible(z_dim=1, cond_dim=0, width=256, depth=4, output_dim=1).to(device); u_model3.load_state_dict(torch.load(f"{model_path}/u_model3_X_alpha={names[1]}.pth")); u_model3.eval()
s_model3 = MLPInstFlexible(z_dim=1, cond_dim=0, width=256, depth=4, output_dim=1).to(device); s_model3.load_state_dict(torch.load(f"{model_path}/s_model3_X_alpha={names[1]}.pth")); s_model3.eval()

def v1_fn(x, t, A): return u_model1(x, t, A)
def s1_fn(x, t, A): return s_model1(x, t, A)
def v2_fn(x, t): return u_model3(x, t)
def s2_fn(x, t): return s_model3(x, t)
def v3_fn(z, t, B): return u_model2(z, t, B)
def s3_fn(z, t, B): return s_model2(z, t, B)
def sigma_fn(t): return 0.5 * torch.ones_like(t)

v_fn_list=[
        lambda x, t: v1_fn(x[:, :1], t, torch.full((x.size(0), 1), A, device=x.device)), # v1(X|A)
        lambda x, t: v2_fn(x[:, :1], t),                                                 # v2(X)
        lambda x, t: v3_fn(x, t, torch.full((x.size(0), 1), B, device=x.device))         # v3(Z|B)
    ]
s_fn_list=[
        lambda x, t: s1_fn(x[:, :1], t, torch.full((x.size(0), 1), A, device=x.device)), # s1(X|A)
        lambda x, t: s2_fn(x[:, :1], t),                                                 # s2(X)
        lambda x, t: s3_fn(x, t, torch.full((x.size(0), 1), B, device=x.device))         # s3(Z|B)
    ]
proj_list=[
        lambda z: z[:, :1],    # project to X 
        lambda z: z[:, :1],    # project to X
        lambda z: z            # identity for Z
    ]
emb_list=[
        lambda x: torch.cat([x, torch.zeros(x.size(0), 1, device=x.device)], dim=1),  # embed X→Z
        lambda x: torch.cat([x, torch.zeros(x.size(0), 1, device=x.device)], dim=1),  # embed X→Z
        lambda z: z  # identity
    ]

print("Models loaded.")
# Out:
# Models loaded.

# %%
# seeds=[0,1,2,3,4]
seeds = [0]
gs = [-1.0, -1.2, -1.4, -1.6, -3, -5, -7]
bs = 5000; n_steps=100
for g in gs:
    results = []
    for seed in seeds:
        torch.manual_seed(seed)
        np.random.seed(seed)
        samples_gt = ground_truth_hcg(bs, cond_A=A, cond_B=B).numpy()
        print(f"Seed set to {seed}")

        print(f"Annealed Temperature = {g}")
        print("Simulating NR")
        gamma_list = [
            lambda t : torch.tensor(1),
            lambda t : torch.tensor(g),
            lambda t : torch.tensor(1)
        ]
        d_gamma_list = [
            lambda t: torch.zeros_like(t),
            lambda t: torch.zeros_like(t),
            lambda t: torch.zeros_like(t)
        ]
        
        x0 = torch.randn(bs, 2).to("cuda")  # (X, Y) sample
        A, B = 1, 1  # Conditioning values
        samples, logw_final, logw_history, sample_history, resample_history = simulate_hcg_generalized(
            x0=x0, v_fn_list=v_fn_list, s_fn_list=s_fn_list, proj_list=proj_list, emb_list=emb_list, sigma_fn=sigma_fn,
            v_star= lambda z, t: v3_fn(z, t, torch.full((z.size(0), 1), B, device=z.device)), 
            t0=0.0, t1=1.0, n_steps=n_steps, device="cuda", ess_threshold=0.90, print_resample_history=True,
            gamma_list=gamma_list,
            d_gamma_list=d_gamma_list,
            resample=False
        )
        samples = samples.cpu().numpy()
        if seed == 0:
            plot_diagnostics(samples, logw_final, logw_history, save_name=f"{experiment_id}/alpha={names}_NR")
            plot_path_trajectories(sample_history, n_frame=6, resample_history=None, experiment_id=experiment_id, name=f"alpha={names}_NR", deg=-50)
            plt.close(); clear_output()
        
        print("Evaluating NR")
        w1, w2, mmd_rbf, total_var = compute_sample_based_metrics(
            torch.tensor(samples_gt), torch.tensor(samples)
        )
        results.append([seed, "NR", w1, w2, mmd_rbf, total_var])

        print("Simulating FKC-H (Constant Gammas)")
        gamma_list = [
            lambda t : torch.tensor(1),
            lambda t : torch.tensor(g),
            lambda t : torch.tensor(1)
        ]
        d_gamma_list = [
            lambda t: torch.zeros_like(t),
            lambda t: torch.zeros_like(t),
            lambda t: torch.zeros_like(t)
        ]

        x0 = torch.randn(bs, 2).to("cuda")  # (X, Y) sample
        A, B = 1, 1  # Conditioning values
        samples, logw_final, logw_history, sample_history, resample_history = simulate_hcg_generalized(
            x0=x0, v_fn_list=v_fn_list, s_fn_list=s_fn_list, proj_list=proj_list, emb_list=emb_list, sigma_fn=sigma_fn,
            v_star= lambda z, t: v3_fn(z, t, torch.full((z.size(0), 1), B, device=z.device)), 
            t0=0.0, t1=1.0, n_steps=n_steps, device="cuda", ess_threshold=0.90, print_resample_history=True,
            gamma_list=gamma_list,
            d_gamma_list=d_gamma_list,
            resample=True
        )
        samples = samples.cpu().numpy()
        if seed == 0:
            plot_diagnostics(samples, logw_final, logw_history, save_name=f"{experiment_id}/alpha={names}_FKC-H")
            plot_path_trajectories(sample_history, n_frame=6, resample_history=None, experiment_id=experiment_id, name=f"alpha={names}_FKC-H", deg=-50)
            plt.close(); clear_output()

        print("Evaluating FKC-H")
        w1, w2, mmd_rbf, total_var = compute_sample_based_metrics(
            torch.tensor(samples_gt), torch.tensor(samples)
        )
        results.append([seed, "FKC-H", w1, w2, mmd_rbf, total_var])

        print("Simulating ACE (Adaptive Gammas)")
        B = 10
        gamma_list = [
            lambda t : torch.tensor(1) + torch.tensor(B * t * (1-t)),
            lambda t : torch.tensor(g),
            lambda t : torch.tensor(1) + torch.tensor(B * t * (1-t))
        ]
        d_gamma_list = [
            lambda t: torch.zeros_like(t) + torch.tensor(B * (1 - 2*t)),
            lambda t: torch.zeros_like(t),
            lambda t: torch.zeros_like(t) + torch.tensor(B * (1 - 2*t))
        ]

        x0 = torch.randn(bs, 2).to("cuda")  # (X, Y) sample
        A, B = 1, 1  # Conditioning values
        samples, logw_final, logw_history, sample_history, resample_history = simulate_hcg_generalized(
            x0=x0, v_fn_list=v_fn_list, s_fn_list=s_fn_list, proj_list=proj_list, emb_list=emb_list, sigma_fn=sigma_fn,
            v_star= lambda z, t: v3_fn(z, t, torch.full((z.size(0), 1), B, device=z.device)), 
            t0=0.0, t1=1.0, n_steps=n_steps, device="cuda", ess_threshold=0.90, print_resample_history=True,
            gamma_list=gamma_list,
            d_gamma_list=d_gamma_list,
            resample=True
        )
        samples = samples.cpu().numpy()
        if seed == 0:
            plot_diagnostics(samples, logw_final, logw_history, save_name=f"{experiment_id}/alpha={names}_ACE")
            plot_path_trajectories(sample_history, n_frame=6, resample_history=None, experiment_id=experiment_id, name=f"alpha={names}_ACE", deg=-50)
            plt.close(); clear_output()

        print("Evaluating ACE")
        w1, w2, mmd_rbf, total_var = compute_sample_based_metrics(
            torch.tensor(samples_gt), torch.tensor(samples)
        )
        results.append([seed, "ACE", w1, w2, mmd_rbf, total_var])

    df = pd.DataFrame(results, columns=["seed", "method", "W1", "W2", "MMD_RBF", "Total Var."])
    df.to_csv(f"{experiment_id}/experiment_results_numseeds{len(seeds)}_bs{bs}_n_steps{n_steps}_g{g}.csv", index=False)
    print(df)
# Out:
# Evaluating ACE
#    seed method        W1        W2   MMD_RBF  Total Var.
# 0     0     NR  1.353715  1.675443  0.191872    0.710800
# 1     0  FKC-H  1.311119  1.558055  0.224418    0.772971
# 2     0    ACE  1.307829  1.530717  0.221172    0.772339

# %%
print(names)
g = -1.6
gamma_list = [
    lambda t : torch.tensor(1),
    lambda t : torch.tensor(g),
    lambda t : torch.tensor(1)
]
d_gamma_list = [
    lambda t: torch.zeros_like(t),
    lambda t: torch.zeros_like(t),
    lambda t: torch.zeros_like(t)
]
Criterion = lambda t: sum([ gamma_list[i](t) / (interpolant_schedules[names[i]].alpha_t(t))**2 for i in range(len(names)) ])

print(f"Criterion(0.99999) = {Criterion(torch.tensor(0.99999)).item()}")

t = torch.linspace(0.01, 0.99, 100)
plt.plot(t.numpy(), Criterion(t).numpy())
plt.xlabel('t')
plt.ylabel('Criterion(t)')
plt.title('Criterion vs t')
plt.grid(True)
plt.savefig(os.path.join(experiment_id, "Criterion_plot.png"))
plt.show()

# print when Criterion = 0
for i in range(len(t)-1):
    if Criterion(t[i]) > 0 and Criterion(t[i+1]) < 0:
        print("Criterion = 0 at t =", t[i].item())
        break
for i in range(len(t)-1):
    if Criterion(t[i]) < 0 and Criterion(t[i+1]) > 0:
        print("Criterion = 0 at t =", t[i].item())
        break
# Out:
# ['sigmoid', 'default_linear', 'default_linear']
# Criterion(0.99999) = -5983736832.0
# Criterion = 0 at t = 0.2178788036108017
# Criterion = 0 at t = 0.6732323169708252

# %%
import numpy as np

def parse_scores(lines):
    # accept either a multiline string or an iterable of lines
    if isinstance(lines, str):
        lines = lines.splitlines()
    scores = []
    for line in lines:
        parts = line.strip().split()
        if not parts:
            continue
        try:
            score = float(parts[-1])  # rightmost number
            scores.append(score)
        except ValueError:
            # ignore lines that don't match the pattern
            continue
    return scores

lines = """len: 16: -8.35445
len: 18: -8.39448
len: 15: -7.81249
len: 14: -6.72482
len: 17: -8.85164
len: 16: -4.54711
len: 17: -6.92383
len: 19: -8.71386
len: 14: -7.03375
len: 17: -8.71458"""

scores = parse_scores(lines)

if not scores:
    print("No scores found.")
else:
    scores = np.array(scores)
    mean = scores.mean()
    std = scores.std()
    min_val = scores.min()

    print(f"Mean: {mean:.5f}")
    print(f"Std: {std:.5f}")
    print(f"Min: {min_val:.5f}")
# Out:
# Mean: -7.60710
# Std: 1.27116
# Min: -8.85164

# %%
# Random code

t = 0.5
one_minus_t_sqrd = (1 - t)**2
t_sqrd = t**2

s_1_n = (one_minus_t_sqrd + 0.5 * t_sqrd)
s_2_n = (one_minus_t_sqrd + 100 * t_sqrd)
s_1_d = (1.5*one_minus_t_sqrd + t_sqrd)
s_2_d = (1.5*one_minus_t_sqrd + t_sqrd)

s_n = 1 / ( (1 / s_1_n) + (1 / s_2_n) )
s_d = 1 / ( (1 / s_1_d) + (1 / s_2_d) )

if s_n < s_d:
    print(f"[YES] s_n < s_d, s_n: {s_n}, s_d: {s_d}")
else:
    print(f"[NO] s_n >= s_d, s_n: {s_n}, s_d: {s_d}")

c = (1/s_n) - (1/s_d)
print(f"c: {c}")
print(f"-(1/2)c: {-0.5*c}")
# Out:
# [NO] s_n >= s_d, s_n: 0.3695121951219512, s_d: 0.3125
# c: -0.493729372937294
# -(1/2)c: 0.246864686468647

# %%
# Random code

t = 0.5
one_minus_t_sqrd = (1 - t)**2
t_sqrd = t**2

s_1_n = (one_minus_t_sqrd + 0.5 * t_sqrd)
s_2_n = (one_minus_t_sqrd + 7 * t_sqrd)
s_1_d = (1.5*one_minus_t_sqrd + t_sqrd)
s_2_d = (1.5*one_minus_t_sqrd + t_sqrd)

s_n = 1 / ( (1 / s_1_n) + (1 / s_2_n) )
s_d = 1 / ( (1 / s_1_d) + (1 / s_2_d) )

if s_n < s_d:
    print(f"[YES] s_n < s_d, s_n: {s_n}, s_d: {s_d}")
else:
    print(f"[NO] s_n >= s_d, s_n: {s_n}, s_d: {s_d}")

c = (1/s_n) - (1/s_d)
print(f"c: {c}")
print(f"-(1/2)c: {-0.5*c}")
# Out:
# [NO] s_n >= s_d, s_n: 0.31578947368421056, s_d: 0.3125
# c: -0.0333333333333341
# -(1/2)c: 0.01666666666666705
